# %% [markdown]
# # Useful Resources
#
# This notebook accompanies the QSAR tutorial chapter: **Useful Resources**.

# %% [markdown]
# This chapter does not require code. Use this notebook to store useful links and package checks.

# %%
import importlib.util

packages = [
    "rdkit",
    "pandas",
    "numpy",
    "matplotlib",
    "sklearn",
    "shap",
    "umap"
]

for package in packages:
    status = "installed" if importlib.util.find_spec(package) else "not installed"
    print(f"{package}: {status}")
